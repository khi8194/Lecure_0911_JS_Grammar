# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.5 MB 11.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.5 MB 11.6 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.5 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 10.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.6 MB 12.2 MB/s eta 0:00:01
#    --------------- ------------------------ 4.7/12.6 MB 11.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.6 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 11.9 MB/s eta 0:00:01
# ...

# %%
pip install openpyxl
# Out:
# ...
#
# ...

# %%
example = [
    ['카테고리1','상품펑1','링크1','가격1'],
    ['카테고리2','상품펑2','링크2','가격2'],
    ['카테고리3','상품펑3','링크3','가격3'],
    ['카테고리4','상품펑4','링크4','가격4']
]
example
# Out:
# [['카테고리1', '상품펑1', '링크1', '가격1'],
#  ['카테고리2', '상품펑2', '링크2', '가격2'],
#  ['카테고리3', '상품펑3', '링크3', '가격3'],
#  ['카테고리4', '상품펑4', '링크4', '가격4']]

# %%
example = []
example.append(['카테고리1','상품펑1','링크1','가격1'])
example.append(['카테고리2','상품펑2','링크2','가격2'])
example.append(['카테고리3','상품펑3','링크3','가격3'])
example.append(['카테고리4','상품펑4','링크4','가격4'])
example
# Out:
# [['카테고리1', '상품펑1', '링크1', '가격1'],
#  ['카테고리2', '상품펑2', '링크2', '가격2'],
#  ['카테고리3', '상품펑3', '링크3', '가격3'],
#  ['카테고리4', '상품펑4', '링크4', '가격4']]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

data=[]
for i in range(1,5):
    response = requests.get(f"https://startcoding.pythonanywhere.com/basic?page={i}")
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')

    items = soup.select('.product')

    for item in items:
        category = item.select_one('.product-category').text
        name = item.select_one('.product-name').text
        link = item.select_one('.product-name>a').attrs['href']
        # price = item.select_one('.product-price').text.strip().split('원')[0]+('원')
        price = item.select_one('.product-price').text.strip().split('원')[0].replace(',','')
        # print(category, name, link, price, sep='\n')
        data.append([category, name, link, price])
data
# Out:
# [['노트북',
#   '에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT',
#   '#product1_detail.html',
#   '1419000'],
#  ['노트북',
#   '삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티엄, 256GB, 8GB, WIN11 Pro',
#   '#product2_detail.html',
#   '549000'],
#  ['노트북',
#   '레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, 82VG002EKR, 라이젠3, Cloud Grey (82VG), 8GB',
#   '#product3_detail.html',
#   '529000'],
#  ['노트북',
#   '레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB, 8GB, WIN11 Home, 82YU0009KR',
#   '#product4_detail.html',
#   '624000'],
#  ['노트북',
#   'LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN11 Home, 16U70R-GA56K',
#   '#product5_detail.html',
#   '1135000'],
#  ['노트북',
#   '베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN11 Pro, 셀러론, 8GB',
#   '#product6_detail.html',
#   '398000'],
#  ['노트북',
#   '레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 512GB, 16GB, Free DOS, 82XD002XKR',
#   '#product7_detail.html',
#   '899000'],
#  ['노트북',
# ...

# %%
#데이터프레임 만들기
df = pd.DataFrame(data, columns=['category','name','link','price' ])
df
# Out:
#    category                                               name  \
# 0       노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB...
# 1       노트북  삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티...
# 2       노트북  레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, ...
# 3       노트북  레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB,...
# 4       노트북  LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN...
# 5       노트북  베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN1...
# 6       노트북  레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 5...
# 7       노트북  레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 1...
# 8       노트북  에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i5, 512GB, 16GB...
# 9       노트북  삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코...
# 10     데스크탑  한성컴퓨터 데스크탑 화이트 TFG MX4A500 (라이젠5-5600G WIN미포함 ...
# 11     데스크탑  컴집 게이밍 조립식 컴퓨터 본체 배틀그라운드 디아블로4 롤 오버워치2 전문가용 건축...
# 12     데스크탑  HP VICTUS 게이밍 데스크탑 TG02-1000KL (i5-13400F Free...
# 13     데스크탑  델 인스피론 3020 S 슬림 데스크탑 포그 블루 DN3020S-WH02KR (i5...
# ...

# %%
# 엑셀 저장
df.to_excel('상픔상세내역.xlsx', index=False) # index False를 하는 이유는 인덱스가 붙어서 xlsx에 저장되지 않게 하기 위해!

# %%
df.to_clipboard()

# %%
## 데이터를 저장하는 방법도 다양하게 있음.
## 찾아보기...
